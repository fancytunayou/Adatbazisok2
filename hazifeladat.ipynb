-- %%
SELECT MIN(LISTAAR) AS value_min, 
       MAX(LISTAAR) AS value_max, 
       AVG(LISTAAR) AS value_avg, 
       STDEV(LISTAAR) AS value_stddev, 
       VAR(LISTAAR) AS value_var
FROM Termek
WHERE LISTAAR IS NOT NULL
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.023
-- <table><tr><th>value_min</th><th>value_max</th><th>value_avg</th><th>value_stddev</th><th>value_var</th></tr><tr><td>0</td><td>46000</td><td>786,2813067150635</td><td>3602,4811630060694</td><td>12977870,529813562</td></tr></table>

-- %%
SELECT min(MEGNEVEZES) AS value_min_string, 
       Max(MEGNEVEZES) AS value_max_string
FROM Termek
WHERE MEGNEVEZES IS NOT NULL
AND LEN(MEGNEVEZES) > 0
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.083
-- <table><tr><th>value_min_string</th><th>value_max_string</th></tr><tr><td>A föld amelyen élünk - Európa földrajza</td><td>Zseléstoll Lizzy Card</td></tr></table>

-- %%
SELECT TOP 10 MEGNEVEZES AS string, 
        LEN(MEGNEVEZES) AS string_length
FROM Termek
GROUP BY MEGNEVEZES
ORDER BY 2 ASC
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>string</th><th>string_length</th></tr><tr><td>Dvd</td><td>3</td></tr><tr><td>sál</td><td>3</td></tr><tr><td>Álarc</td><td>5</td></tr><tr><td>Körző</td><td>5</td></tr><tr><td>Fizika</td><td>6</td></tr><tr><td>Celofán</td><td>7</td></tr><tr><td>Lampion</td><td>7</td></tr><tr><td>Filctoll </td><td>8</td></tr><tr><td>fiú alsó</td><td>8</td></tr><tr><td>női alsó</td><td>8</td></tr></table>

-- %%
SELECT MIN(LEN(LEIRAS)) AS string_length_min, 
       MAX(LEN(LEIRAS)) AS string_length_max, 
       AVG(LEN(LEIRAS)) AS string_length_avg, 
       STDEV(LEN(LEIRAS)) AS string_length_stddev, 
       VAR(LEN(LEIRAS)) AS string_length_var
FROM Termek
WHERE LEIRAS IS NOT NULL
AND LEN(LEIRAS) > 0
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.046
-- <table><tr><th>string_length_min</th><th>string_length_max</th><th>string_length_avg</th><th>string_length_stddev</th><th>string_length_var</th></tr><tr><td>5</td><td>19</td><td>11</td><td>4,1491661463654275</td><td>17,215579710144933</td></tr></table>

-- %%
SELECT row_type,
    COUNT(*) row_count
FROM 
    (SELECT 
        CASE WHEN LEIRAS IS NULL THEN 'Null'
            ELSE 'Non Empty' 
            END AS row_type
        FROM Termek) rows
GROUP BY row_type
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>row_type</th><th>row_count</th></tr><tr><td>Non Empty</td><td>24</td></tr><tr><td>Null</td><td>527</td></tr></table>

-- %%
SELECT COUNT(DISTINCT KAT_ID) AS unique_values_count
FROM Termek
WHERE KAT_ID IS NOT NULL
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>unique_values_count</th></tr><tr><td>143</td></tr></table>
